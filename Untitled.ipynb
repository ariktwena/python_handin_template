# %%
import string

class TextContainer():
    """A simple book model consisting of chapters, which in 
    turn consist of paragraphs."""

    def __init__(self, text):
        """Initialize title, the author, and the chapters."""
        self.text = text
    
    def count_words(self):
        wordlist = self.text.split()      
        return len(wordlist)    
    
    def number_of_chars(self):
        letter_list = list(self.text)
        count = 0
        for letter in letter_list:
            if letter.isalpha():
                #print(letter)
                count = count + 1
        return count
    
    def number_of_letter(self):
        count = 0
        for letter in self.text:
            if letter in string.ascii_letters:
                #print(letter)
                count = count + 1
        return count
    
    def number_of_punctuation(self):
        count = 0
        for letter in self.text:
            if letter in string.punctuation:
                #print(letter)
                count = count + 1
        return count

# %%
string.ascii_letters
# Out:
# 'abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ'

# %%
string.punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
tc = TextContainer("Dette er en tekst!?")

# %%
# Number of words
tc.count_words()
# Out:
# 4

# %%
# Number of chars
tc.number_of_chars()
# Out:
# 14

# %%
tc.number_of_letter()
# Out:
# 14

# %%
tc.number_of_punctuation()
# Out:
# 2

# %%
import matplotlib.pyplot as plt

# %%
student_attendance = {'day1':33, 'day2':34,'day3':29,'day4':31,'day5':28,'day6':26,'day7':30}

# %%
student_attendance
# Out:
# {'day1': 33,
#  'day2': 34,
#  'day3': 29,
#  'day4': 31,
#  'day5': 28,
#  'day6': 26,
#  'day7': 30}

# %%
# %matplotlib notebook
plt.figure()

x_values = student_attendance.keys()
y_values = student_attendance.values()

print('Points to be plotted {}'.format(list(zip(x_values, y_values)))) # The purpose of zip() is to map the similar index of multiple containers so that they can be used just using as single entity. 
      
plt.scatter(x_values, y_values, s=100)
# Out:
# <img src="data:image/png;base64,..." width="640">
# Points to be plotted [('day1', 33), ('day2', 34), ('day3', 29), ('day4', 31), ('day5', 28), ('day6', 26), ('day7', 30)]
